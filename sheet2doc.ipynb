# %%
import pandas as pd

# %%
sheetname = '[Confidential] Calibration sheet - L6 Acceleration & OS (Group 1) - CALIBRATION GROUP.csv'
mdname = sheetname[:-3]+'md'
datas = pd.read_csv(sheetname)

# %%
def template(row):
    return """
# {person}
{level} {title}
Manager: {manager}

## Competencies

### ROLE Competencies {role_comp_rating}

{role_comp_expl}

### LEADERSHIP Competencies {role_comp_rating}

{role_comp_expl}

## Impact

### OKRs

{okrs}

### Blockers

{blockers}

## Development Areas

{development_areas}

## Others Comments

{others}

## Feedback and Final Rating

WNH:
WNL:

Rating: 

""".format(
    person=row['Employee Name'],
    manager=row['Manager Name'],
    title=row['Employee Job Title'],
    level=row['Employee Job Title Level'],
    role_comp_rating=row['ROLE Competencies Rating'],
    role_comp_expl=row['ROLE Competencies Explanation'],
    leader_comp_rating=row['LEADERSHIP Competencies Rating'],
    leader_comp_expl=row['LEADERSHIP Competencies Explanation'],
    external_feedback=row['External Feedback'],
    okrs=row['OKRs Rating'],
    blockers=row['Blockers/Challenges'],	
    development_areas=row['Development Areas'],
    others=row['Any other comments'],
)

# %%
with open(mdname, "w") as fd:
    for i in range(0, datas.shape[0]):
        row = datas.iloc[i]
        fd.write(template(row))

# %%
for i in range(0, datas.shape[0]):
    row = datas.iloc[i]
    print(template(row))
# Out:
# # Clare Booth
# Level 6 Director of Employment Law & Policy
# Manager: Antony Lias
#
# ## Competencies
#
# ### ROLE Competencies 4 - EE - Exceeding Expectations
#
# - Legal Knowledge/Strategy/Planning: (EE) - Clare’s legal knowledge is formidable and this ought to be an SEE however, her planning and prioritisation of work brings this grade down to EE. I’m impressed by how skilfully she helped us deliver an extremely safe offboarding programme, reducing massively our reliance on sub-optimal external lawyers. She’s also taken over legal matters for us for Germany, Portugal and Switzerland, enabling her to be our lead on any legal disputes or contractual questions.
#
# - Contract Review/Negotiation: (SEE) As mentioned above and elsewhere, her work on new style templates and safe approaches to legal disputes as well as negotiations (invariably advisory) has been exceptional. It’s more than 6 months of very high achievement.
#
# - Risk Management & Compliance: (EE) Clare often advises me and the team on the various compliance risks we face and recommends excellent strategies for overcoming them. She is extremely thoughtful and creative in providing solutions which can work for Parity. The offboarding programme risk was her primary achievement in this area, along with changes to our newly updated contracts reflecting comp changes.
#
# ### LEADERSHIP Competencies 4 - EE - Exceeding Expectations
#
# - Legal Knowledge/Strategy/Planning: (EE) - Clare’s legal knowledge is formidable and this ought to be an SEE however, her planning and prioritisation of work brings this grade down to EE. I’m impressed by how skilfully she helped us deliver an extremely safe offboarding programme, reducing massively our reliance on sub-optimal external lawyers. She’s also taken over legal matters for us for Germany, Portugal and Switzerland, enabling her to be our lead on any legal disputes or contractual questions.
#
# - Contract Review/Negotiation: (SEE) As mentioned above and elsewhere, her work on new style templates and safe approaches to legal disputes as well as negotiations (invariably advisory) has been exceptional. It’s more than 6 months of very high achievement.
#
# - Risk Management & Compliance: (EE) Clare often advises me and the team on the various compliance risks we face and recommends excellent strategies for overcoming them. She is extremely thoughtful and creative in providing solutions which can work for Parity. The offboarding programme risk was her primary achievement in this area, along with changes to our newly updated contracts reflecting comp changes.
#
# ## Impact
#
# ### OKRs
#
# 4 - EE - Exceeds Expectations
#
# ### Blockers
#
# - Lack of Legal Resources/Support: Having just 1 in-house employment lawyer during such a challenging period was tough. Clare managed everything as well as she could, but we needed to be guided by her on the support needed. Her decision to jettison B&B on the contract work came too late for us to practically resolve the matter, meaning that Clare pretty much did everything
#
# - Last minute requests: There have been plenty of challenging last minute requests, including two high profile contracts. Parity cannot have the same amount of flexibility with far fewer resources. This is something Chrissy and I need to work on, but in the meantime novel situations must be managed.
#
# -
#
# ## Development Areas
#
# - Communication (See above)
#
# - Planning (See above)
#
# -
#
# ## Others Comments
#
# I think Clare deserves an EE rating purely for her immense achievements, so perhaps this is the correct outcome, but there are several key areas in need of improvement. CME is therefore appropriate. I do expect Clare to achieve EE status, as we are already helping her with Asana management, task planning and shortly, comms delivery.
#
# ## Feedback and Final Rating
#
# WNH:
# WNL:
#
# Rating:
#
#
#
# # Joseph Petrowski
# Level 6 Research Analyst
# Manager: Pierre Aubert
#
# ## Competencies
#
# ### ROLE Competencies 3 - CME - Consistently Meeting Expectations
#
# - At L6, Joe is doing a good job managing a fairly large team with multiple products.
#
# - He does deliver a fair amount of projects and overall execution is good.
#
# - A few things are still missing to get a very effective team: roadmap, okr and strategy are still on the learning curve.
#
# - Bonus point for an excellent job on hiring.
#
# ### LEADERSHIP Competencies 3 - CME - Consistently Meeting Expectations
#
# - At L6, Joe is doing a good job managing a fairly large team with multiple products.
#
# - He does deliver a fair amount of projects and overall execution is good.
#
# - A few things are still missing to get a very effective team: roadmap, okr and strategy are still on the learning curve.
#
# - Bonus point for an excellent job on hiring.
#
# ## Impact
#
# ### OKRs
#
# 3 - CME - Consistently Meets Expectations
#
# ### Blockers
#
# - Lots of turnover
#
# ## Development Areas
#
# - Improve oral communication and be more mindful of how he is perceived
#
# - Build a better team culture that scale with the expended scope.
#
# - Keeping a healthy work life balance (we have seen sign of being overworked)
#
# ## Others Comments
#
# - Very strong CME and I could be swayed for EE
#
# - Potential is there to go higher but high impact is still not there.
#
# -
#
# ## Feedback and Final Rating
#
# WNH:
# WNL:
#
# Rating:
#
#
#
# # Karim Jedda
# Level 6 Lead Data Engineer
# Manager: Pierre Aubert
#
# ## Competencies
#
# ### ROLE Competencies 3 - CME - Consistently Meeting Expectations
#
# - Karim is managing his teams closely with good level of delegation.
#
# - Some aspects are excellent, see OKR review for example.
#
# -
#
# ### LEADERSHIP Competencies 3 - CME - Consistently Meeting Expectations
#
# - Karim is managing his teams closely with good level of delegation.
#
# - Some aspects are excellent, see OKR review for example.
#
# -
#
# ## Impact
#
# ### OKRs
#
# 3 - CME - Consistently Meets Expectations
#
# ### Blockers
#
# - Not too many
#
# -
#
# -
#
# ## Development Areas
#
# - Karim has many challenges: on the leadership side, he needs to coach and then delegate to Alberto the future of Success. With the community, Karim needs to prove he can be perceived as a trusted person and he will need to sharpen is communication and leadership style and make it more adaptative to the context.
#
# ## Others Comments
#
# - Karim has everything to get to L7 but he needs a track record and a lot more impact.
#
# - To go to L6+ I want to see a roadmap negotiated with the ecosystem and success on the B2B path.
#
# - As a reference point, Karim would get L6 CME  at Google for a large scope but unclear delivery.
#
# ## Feedback and Final Rating
#
# WNH:
# WNL:
#
# Rating:
#
#
#
# # Robert Klotzner
# Level 6 Software Developer
# Manager: Pierre Aubert
#
# ## Competencies
#
# ### ROLE Competencies 4 - EE - Exceeding Expectations
#
# - Robert is a good manager (see peer feedback) and has also strong technical skills which help him to lead.
#
# - To improve:
#
#   - Management : tighten the screws on OKR and delivery
#
#   - Communication: good written communication and I would love to see more oral communication outside of Parity
#
#   - Not proactif enough outside of his area.
#
# ### LEADERSHIP Competencies 4 - EE - Exceeding Expectations
#
# - Robert is a good manager (see peer feedback) and has also strong technical skills which help him to lead.
#
# - To improve:
#
#   - Management : tighten the screws on OKR and delivery
#
#   - Communication: good written communication and I would love to see more oral communication outside of Parity
#
#   - Not proactif enough outside of his area.
#
# ## Impact
#
# ### OKRs
#
# 4 - EE - Exceeds Expectations
#
# ### Blockers
#
# - Blockers: attrition
#
# -
#
# -
#
# ## Development Areas
#
# - I would like Robert to be more focus on Parity success. What do we need to build?
#
# - I want to see a roadmap for scaling the node (potentially a lot) and improve reliability (DDoS)
#
# ## Others Comments
#
# - Solid L6 CME
#
# - Reference point: would be rated the same at G.
#
# -
#
# ## Feedback and Final Rating
#
# WNH:
# WNL:
#
# Rating:
#
#
#
# # Eva Wong
# Level 6 Director of Legal
# Manager: Christina Hill
#
# ## Competencies
#
# ### ROLE Competencies 4 - EE - Exceeding Expectations
#
# - Generally I think Eva needs to work on Risk Management & Compliance needs to be a focus going forward. She needs to take a longer term strategic view on issues and not just put out the fire in front of her. This has been difficult to do considering the pace and extent of change over the last 6 months, but I hope she’ll be able to devote more time in the rest of 2024
#
# - Eva is a safe pair of hands and will get all the technical legal aspects of any transaction or discussion thoroughly researched and covered. I would like to see her take more of a leadership role with other teams.
#
# - Eva has worked hard to raise her profile in the ecosystem and industry. I think this is hugely positive for her confidence. I hope this continues.
#
# ### LEADERSHIP Competencies 4 - EE - Exceeding Expectations
#
# - Generally I think Eva needs to work on Risk Management & Compliance needs to be a focus going forward. She needs to take a longer term strategic view on issues and not just put out the fire in front of her. This has been difficult to do considering the pace and extent of change over the last 6 months, but I hope she’ll be able to devote more time in the rest of 2024
#
# - Eva is a safe pair of hands and will get all the technical legal aspects of any transaction or discussion thoroughly researched and covered. I would like to see her take more of a leadership role with other teams.
#
# - Eva has worked hard to raise her profile in the ecosystem and industry. I think this is hugely positive for her confidence. I hope this continues.
#
# ## Impact
#
# ### OKRs
#
# 3 - CME - Consistently Meets Expectations
#
# ### Blockers
#
# - Low morale, a team cut in half, Flor’s departure and unexpected asks related to the Parity transformation
#
# - Eva at times is too detailed oriented and can get bogged down. Applying a 80/20 rule would be more appropriate at times
#
# ## Development Areas
#
# - Innovation - she needs to be thinking like Tomorrow’s Lawyers
#
# - Risk Management - need to refocus on this for the rest of 2024
#
# -
#
# ## Others Comments
#
# nan
#
# ## Feedback and Final Rating
#
# WNH:
# WNL:
#
# Rating:
